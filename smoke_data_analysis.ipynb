# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tobacco_data = pd.read_csv("tobacco.csv")
tobacco_data
# Out:
#      Year                       State Smoke everyday Smoke some days  \
# 0    1996                 Puerto Rico          9.40%           5.10%
# 1    1997                 Puerto Rico          9.40%              5%
# 2    1998                 Puerto Rico         10.10%           5.20%
# 3    1999                 Puerto Rico          9.70%              4%
# 4    2000                 Puerto Rico          9.20%           3.90%
# ..    ...                         ...            ...             ...
# 871  1995  Nationwide (States and DC)         19.90%           2.60%
# 872  2010                        Guam         19.70%           6.10%
# 873  2009                        Guam         18.90%           5.20%
# 874  2010              Virgin Islands          3.60%           2.20%
# 875  2009              Virgin Islands          3.90%           2.60%
#
#     Former smoker Never smoked           Location 1
# 0             16%       69.50%        Puerto Rico\n
# ...

# %%
tobacco_data.isnull().sum()
# Out:
# Year                0
# State               0
# Smoke everyday      0
# Smoke some days     0
# Former smoker       0
# Never smoked        0
# Location 1         37
# dtype: int64

# %%
sns.heatmap(tobacco_data.isnull())
plt.show()

# %%
tobacco_data["Location 1"].mode()[0]
# Out:
# 'Alabama\n(32.840569999605975, -86.63186000013877)'

# %%
tobacco_data.fillna(tobacco_data["Location 1"].mode()[0] , inplace =True)

# %%
tobacco_data.isnull().sum()
# Out:
# Year               0
# State              0
# Smoke everyday     0
# Smoke some days    0
# Former smoker      0
# Never smoked       0
# Location 1         0
# dtype: int64

# %%
tobacco_data["Year"].value_counts()
# Out:
# Year
# 2001    56
# 2002    56
# 2003    56
# 2007    56
# 2008    56
# 2009    56
# 2010    56
# 2005    55
# 2006    55
# 1997    54
# 1998    54
# 1999    54
# 2000    54
# 2004    54
# 1996    53
# 1995    51
# Name: count, dtype: int64

# %%
tobacco_data["State"].value_counts()
# Out:
# State
# Iowa                                        16
# Michigan                                    16
# Kansas                                      16
# Rhode Island                                16
# New Hampshire                               16
# New Mexico                                  16
# Maryland                                    16
# Minnesota                                   16
# Ohio                                        16
# New Jersey                                  16
# Texas                                       16
# Arkansas                                    16
# Alaska                                      16
# Colorado                                    16
# California                                  16
# North Dakota                                16
# Arizona                                     16
# Pennsylvania                                16
# Wyoming                                     16
# West Virginia                               16
# ...

# %%
plt.figure(figsize = (15,5))
sns.scatterplot(x = "State" , y = "Year" , data = tobacco_data)
plt.xticks(rotation= 90)
plt.show()

# %%
tobacco_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 876 entries, 0 to 875
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             876 non-null    int64
#  1   State            876 non-null    object
#  2   Smoke everyday   876 non-null    object
#  3   Smoke some days  876 non-null    object
#  4   Former smoker    876 non-null    object
#  5   Never smoked     876 non-null    object
#  6   Location 1       876 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 48.0+ KB

# %%
tobacco_data.describe()
# Out:
#               Year  Smoke everyday_float  Smoke some days_float  \
# count   876.000000            876.000000             876.000000
# mean   2002.591324             16.555479               4.839498
# std       4.593622              3.981661               1.156771
# min    1995.000000              3.600000               1.300000
# 25%    1999.000000             13.900000               4.200000
# 50%    2003.000000             16.700000               4.900000
# 75%    2007.000000             19.100000               5.525000
# max    2010.000000             29.100000               8.500000
#
#        Former smoker_float  Never smoked_float
# count           876.000000          876.000000
# mean             24.321918           54.257306
# std               3.501092            5.603022
# min               9.900000           39.500000
# 25%              22.900000           51.075000
# 50%              24.500000           53.500000
# 75%              26.200000           56.200000
# ...

# %%
tobacco_data["Smoke everyday_float"]= tobacco_data["Smoke everyday"].str.replace("%" ,"").astype(float)

# %%
tobacco_data["Smoke some days_float"]= tobacco_data["Smoke some days"].str.replace("%" ,"").astype(float)

# %%
tobacco_data["Former smoker_float"]= tobacco_data["Former smoker"].str.replace("%" ,"").astype(float)

# %%
tobacco_data["Never smoked_float"]= tobacco_data["Never smoked"].str.replace("%" ,"").astype(float)

# %%
tobacco_data
# Out:
#      Year                       State Smoke everyday Smoke some days  \
# 0    1996                 Puerto Rico          9.40%           5.10%
# 1    1997                 Puerto Rico          9.40%              5%
# 2    1998                 Puerto Rico         10.10%           5.20%
# 3    1999                 Puerto Rico          9.70%              4%
# 4    2000                 Puerto Rico          9.20%           3.90%
# ..    ...                         ...            ...             ...
# 871  1995  Nationwide (States and DC)         19.90%           2.60%
# 872  2010                        Guam         19.70%           6.10%
# 873  2009                        Guam         18.90%           5.20%
# 874  2010              Virgin Islands          3.60%           2.20%
# 875  2009              Virgin Islands          3.90%           2.60%
#
#     Former smoker Never smoked  \
# 0             16%       69.50%
# 1          15.70%       69.90%
# 2          16.80%       67.90%
# ...

# %%
plt.figure(figsize = (15,5))
sns.stripplot(x= "State" , y = "Smoke everyday_float" , data = tobacco_data ,hue ="State",palette = "viridis_r")
plt.grid()
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (15,5))
sns.stripplot(x= "State" , y = "Smoke some days_float" , data = tobacco_data ,hue ="State",palette ="gist_earth")
plt.grid()
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (15,5))
sns.stripplot(x= "State" , y = "Former smoker_float" , data = tobacco_data ,hue ="State",palette ="gist_earth")
plt.grid()
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (15,5))
sns.stripplot(x= "State" , y = "Former smoker_float" , data = tobacco_data ,hue ="State", palette ="Dark2")
plt.grid()
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (15,5))
sns.pairplot(tobacco_data,hue = "State" , kind ="hist",diag_kind = "kde")

plt.show()
